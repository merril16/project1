# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')

# %%
df.head(10)
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
# 5   Life expectancy at birth (years)      Published  2000
# 6  Life expectancy at age 60 (years)      Published  1990
# 7  Life expectancy at age 60 (years)      Published  2012
# 8   Life expectancy at birth (years)      Published  2012
# 9   Life expectancy at birth (years)      Published  2000
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# ...

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')

# %%
df1.head()
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %% [markdown]
# ## 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %% [markdown]
# ## 2

# %%
np.array(df.index)
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
np.array(df1.index)
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %% [markdown]
# ## 3   4  5  6

# %%
df1.columns
# Out:
# Index(['STATION', 'STATION_NAME', 'DATE', 'PRCP', 'SNWD', 'SNOW', 'TMAX',
#        'TMIN', 'WDFG', 'PGTM', 'WSFG', 'WT09', 'WT07', 'WT01', 'WT06', 'WT05',
#        'WT04', 'WT16', 'WT08', 'WT18', 'WT03'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
df.rename(columns={'Indicator' :  'indicator_id','PUBLISH STATES':'publication status','WHO region':'WHO Region'},inplace=True)

# %%
df.head()
# Out:
#                         indicator_id publication status  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %% [markdown]
# ##  6

# %%
sorted(df['Year'])
# Out:
# [1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
#  1990,
# ...

# %%
df.sort_values('Year',ascending = True)
# Out:
#                                          indicator_id publication status  \
# 0                    Life expectancy at birth (years)          Published
# 1270                 Life expectancy at birth (years)          Published
# 3193                 Life expectancy at birth (years)          Published
# 3194                 Life expectancy at birth (years)          Published
# 3197                Life expectancy at age 60 (years)          Published
# 1264                 Life expectancy at birth (years)          Published
# 3199                Life expectancy at age 60 (years)          Published
# 1262                Life expectancy at age 60 (years)          Published
# 1259                 Life expectancy at birth (years)          Published
# 3203                Life expectancy at age 60 (years)          Published
# 1273                Life expectancy at age 60 (years)          Published
# 3204                 Life expectancy at birth (years)          Published
# ...

# %%
df.sort_values(by=['indicator_id','Country','Year','WHO Region','publication status'],ascending=True)
# Out:
#                                          indicator_id publication status  \
# 2798  Healthy life expectancy (HALE) at birth (years)          Published
# 3363  Healthy life expectancy (HALE) at birth (years)          Published
# 4456  Healthy life expectancy (HALE) at birth (years)          Published
# 2245  Healthy life expectancy (HALE) at birth (years)          Published
# 3689  Healthy life expectancy (HALE) at birth (years)          Published
# 4457  Healthy life expectancy (HALE) at birth (years)          Published
# 2598  Healthy life expectancy (HALE) at birth (years)          Published
# 3690  Healthy life expectancy (HALE) at birth (years)          Published
# 3691  Healthy life expectancy (HALE) at birth (years)          Published
# 2599  Healthy life expectancy (HALE) at birth (years)          Published
# 3692  Healthy life expectancy (HALE) at birth (years)          Published
# 4064  Healthy life expectancy (HALE) at birth (years)          Published
# ...

# %%
df.drop(['World Bank income group','Sex','Display Value','Numeric','Low','High','Comments'],axis=1)
# Out:
#                                          indicator_id publication status  \
# 0                    Life expectancy at birth (years)          Published
# 1                    Life expectancy at birth (years)          Published
# 2                   Life expectancy at age 60 (years)          Published
# 3                   Life expectancy at age 60 (years)          Published
# 4                    Life expectancy at birth (years)          Published
# 5                    Life expectancy at birth (years)          Published
# 6                   Life expectancy at age 60 (years)          Published
# 7                   Life expectancy at age 60 (years)          Published
# 8                    Life expectancy at birth (years)          Published
# 9                    Life expectancy at birth (years)          Published
# 10                   Life expectancy at birth (years)          Published
# 11                   Life expectancy at birth (years)          Published
# ...

# %% [markdown]
# ## 8

# %%
df=df[['Country','indicator_id','publication status','Year','WHO Region','World Bank income group','Sex','Display Value','Numeric','Low','High','Comments']]

# %%
df
# Out:
#                                  Country  \
# 0                                Andorra
# 1                                Andorra
# 2                                Andorra
# 3                                Andorra
# 4                   United Arab Emirates
# 5                    Antigua and Barbuda
# 6                    Antigua and Barbuda
# 7                    Antigua and Barbuda
# 8                              Australia
# 9                              Australia
# 10                             Australia
# 11                               Austria
# 12                               Austria
# 13                               Belgium
# 14                               Bahrain
# 15                               Bahrain
# 16                               Bahrain
# 17                               Bahamas
# 18                               Bahamas
# 19                              Barbados
# 20                              Barbados
# 21                              Barbados
# ...

# %% [markdown]
# ## 9

# %%
np.array(df['WHO Region'])
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'], dtype=object)

# %% [markdown]
# ## 11

# %%
df.drop(df.index[[5,12,23,36]])
# Out:
#                                  Country  \
# 0                                Andorra
# 1                                Andorra
# 2                                Andorra
# 3                                Andorra
# 4                   United Arab Emirates
# 6                    Antigua and Barbuda
# 7                    Antigua and Barbuda
# 8                              Australia
# 9                              Australia
# 10                             Australia
# 11                               Austria
# 13                               Belgium
# 14                               Bahrain
# 15                               Bahrain
# 16                               Bahrain
# 17                               Bahamas
# 18                               Bahamas
# 19                              Barbados
# 20                              Barbados
# 21                              Barbados
# 22                     Brunei Darussalam
# 24                     Brunei Darussalam
# ...

# %%
sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
products = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')

users.head()
sessions.head()
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %%
users.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessions.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %% [markdown]
# ## 12

# %%
merged_left = pd.merge(left=transactions,right=users, how='left', left_on='TransactionID', right_on='UserID')

# %%
merged_left
# Out:
#    TransactionID TransactionDate  UserID_x  ProductID  Quantity  UserID_y  \
# 0              1      2010-08-21       7.0          2         1       1.0
# 1              2      2011-05-26       3.0          4         1       2.0
# 2              3      2011-06-16       3.0          3         1       3.0
# 3              4      2012-08-26       1.0          2         3       4.0
# 4              5      2013-06-06       2.0          4         1       5.0
# 5              6      2013-12-23       2.0          5         6       NaN
# 6              7      2013-12-30       3.0          4         1       NaN
# 7              8      2014-04-24       NaN          2         3       NaN
# 8              9      2015-04-24       7.0          4         3       NaN
# 9             10      2016-05-08       3.0          4         4       NaN
#
#        User  Gender  Registered   Cancelled
# 0   Charles    male  2012-12-21         NaN
# 1     Pedro    male  2010-08-01  2010-08-08
# ...

# %%
transactions.loc[merged_left['UserID_x'].isin(users['UserID'])]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 9             10      2016-05-08     3.0          4         4

# %% [markdown]
# ## 14

# %%
transactions.join(users.set_index(['UserID']), on='UserID',how='inner').reset_index().drop('index',axis=1)
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26      3          4         1  Caroline
# 1              3      2011-06-16      3          3         1  Caroline
# 2              7      2013-12-30      3          4         1  Caroline
# 3             10      2016-05-08      3          4         4  Caroline
# 4              4      2012-08-26      1          2         3   Charles
# 5              5      2013-06-06      2          4         1     Pedro
# 6              6      2013-12-23      2          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %% [markdown]
# ##  15

# %%
transactions.join(users.set_index(['UserID']), on='UserID',how='outer').reset_index().drop('index',axis=1)
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %% [markdown]
# ## 16

# %%
sessions
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4
# 5          6  2012-10-23       4
# 6          7  2012-12-21       3
# 7          8  2013-05-22       4
# 8          9  2013-07-17       4
# 9         10  2016-01-11       4

# %%
users
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
merged_sess = pd.merge(left=sessions,right=users, how='right', on='UserID')

# %%
merged_sess
# Out:
#     SessionID SessionDate  UserID      User  Gender  Registered   Cancelled
# 0         1.0  2010-01-05       2     Pedro    male  2010-08-01  2010-08-08
# 1         2.0  2010-08-01       2     Pedro    male  2010-08-01  2010-08-08
# 2         3.0  2010-11-25       2     Pedro    male  2010-08-01  2010-08-08
# 3         4.0  2011-09-21       5  Benjamin    male  2010-11-25         NaN
# 4         5.0  2011-10-19       4   Brielle  female  2013-07-17         NaN
# 5         6.0  2012-10-23       4   Brielle  female  2013-07-17         NaN
# 6         8.0  2013-05-22       4   Brielle  female  2013-07-17         NaN
# 7         9.0  2013-07-17       4   Brielle  female  2013-07-17         NaN
# 8        10.0  2016-01-11       4   Brielle  female  2013-07-17         NaN
# 9         7.0  2012-12-21       3  Caroline  female  2012-10-23  2016-06-07
# 10        NaN         NaN       1   Charles    male  2012-12-21         NaN

# %% [markdown]
# ## 17

# %%
merged_sess.loc[merged_sess['SessionDate'].isin(users['Registered'])]
# Out:
#    SessionID SessionDate  UserID      User  Gender  Registered   Cancelled
# 1        2.0  2010-08-01       2     Pedro    male  2010-08-01  2010-08-08
# 2        3.0  2010-11-25       2     Pedro    male  2010-08-01  2010-08-08
# 5        6.0  2012-10-23       4   Brielle  female  2013-07-17         NaN
# 7        9.0  2013-07-17       4   Brielle  female  2013-07-17         NaN
# 9        7.0  2012-12-21       3  Caroline  female  2012-10-23  2016-06-07

# %% [markdown]
# ## 18

# %%
x=pd.DataFrame({'key':np.repeat(1,users.shape[0]),'UserID':users.UserID})

# %%
x
# Out:
#    UserID  key
# 0       1    1
# 1       2    1
# 2       3    1
# 3       4    1
# 4       5    1

# %%
y=pd.DataFrame({'key':np.repeat(1,transactions.shape[0]),'ProductID':transactions.ProductID})

# %%
y
# Out:
#    ProductID  key
# 0          2    1
# 1          4    1
# 2          3    1
# 3          2    1
# 4          4    1
# 5          5    1
# 6          4    1
# 7          2    1
# 8          4    1
# 9          4    1

# %%
r=pd.merge(y,x,on='key')

# %%
r
# Out:
#     ProductID  key  UserID
# 0           2    1       1
# 1           2    1       2
# 2           2    1       3
# 3           2    1       4
# 4           2    1       5
# 5           4    1       1
# 6           4    1       2
# 7           4    1       3
# 8           4    1       4
# 9           4    1       5
# 10          3    1       1
# 11          3    1       2
# 12          3    1       3
# 13          3    1       4
# 14          3    1       5
# 15          2    1       1
# 16          2    1       2
# 17          2    1       3
# 18          2    1       4
# 19          2    1       5
# 20          4    1       1
# 21          4    1       2
# 22          4    1       3
# 23          4    1       4
# 24          4    1       5
# 25          5    1       1
# 26          5    1       2
# 27          5    1       3
# 28          5    1       4
# 29          5    1       5
# 30          4    1       1
# 31          4    1       2
# 32          4    1       3
# ...
